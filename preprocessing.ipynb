# %%
from utils import *
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\danie\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\danie\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package product_reviews_2 to
# [nltk_data]     C:\Users\danie\AppData\Roaming\nltk_data...
# [nltk_data]   Package product_reviews_2 is already up-to-date!

# %%
train_df_orig = load_dataset('local', 'train.tsv')
train_df = train_df_orig

test_df_orig = load_dataset('local', 'test.tsv')
test_df = test_df_orig

# test2_df_orig = load_dataset('local', 'test_stg2.tsv')
# test2_df = test2_df_orig

# %%
train_df
# Out:
#                                            name  item_condition_id  \
# train_id
# 0           MLB Cincinnati Reds T Shirt Size XL                  3
# 1              Razer BlackWidow Chroma Keyboard                  3
# 2                                AVA-VIV Blouse                  1
# 3                         Leather Horse Statues                  1
# 4                          24K GOLD plated rose                  1
# ...                                         ...                ...
# 1482530              Free People Inspired Dress                  2
# 1482531           Little mermaid handmade dress                  2
# 1482532   21 day fix containers and eating plan                  2
# 1482533                  World markets lanterns                  3
# 1482534           Brand new lux de ville wallet                  1
#
#                                               category_name   brand_name  \
# train_id
# 0                                         Men/Tops/T-shirts          NaN
# 1         Electronics/Computers & Tablets/Components & P...        Razer
# 2                               Women/Tops & Blouses/Blouse       Target
# 3                        Home/Home Décor/Home Décor Accents          NaN
# 4                                   Women/Jewelry/Necklaces          NaN
# ...                                                     ...          ...
# 1482530                              Women/Dresses/Mid-Calf  Free People
# 1482531                            Kids/Girls 2T-5T/Dresses       Disney
# 1482532      Sports & Outdoors/Exercise/Fitness accessories          NaN
# 1482533                  Home/Home Décor/Home Décor Accents          NaN
# 1482534                   Women/Women's Accessories/Wallets          NaN
#
#           price  shipping                                   item_description
# train_id
# 0          10.0         1                                 No description yet
# 1          52.0         0  This keyboard is in great condition and works ...
# 2          10.0         1  Adorable top with a hint of lace and a key hol...
# 3          35.0         1  New with tags. Leather horses. Retail for [rm]...
# 4          44.0         0          Complete with certificate of authenticity
# ...         ...       ...                                                ...
# 1482530    20.0         1  Lace, says size small but fits medium perfectl...
# 1482531    14.0         0   Little mermaid handmade dress never worn size 2t
# 1482532    12.0         0          Used once or twice, still in great shape.
# 1482533    45.0         1  There is 2 of each one that you see! So 2 red ...
# 1482534    22.0         0  New with tag, red with sparkle. Firm price, no...
#
# [1482535 rows x 7 columns]

# %%
train_df = preprocess(train_df)
train_df.to_csv('train_pp2.csv')
X_train, y_train = extract_from_trainset(train_df)

# %%
X_train
# Out:
#           item_condition_id  shipping      vec0      vec1      vec2      vec3  \
# train_id
# 0                         3         1 -0.007633  0.013877  0.001542  0.002168
# 1                         3         0  0.013427 -0.005142  0.006128  0.001119
# 2                         1         1  0.001426 -0.006458  0.002439  0.008610
# 3                         1         1  0.005893 -0.008465  0.012312 -0.003756
# 4                         1         0  0.008761  0.012107 -0.013877 -0.008480
# ...                     ...       ...       ...       ...       ...       ...
# 1482530                   2         1  0.011897  0.014751  0.014285  0.005974
# 1482531                   2         0 -0.005538  0.011826 -0.014858 -0.004269
# 1482532                   2         0 -0.004339 -0.001035 -0.013800 -0.014500
# 1482533                   3         1  0.009275 -0.002209  0.007089  0.014941
# 1482534                   1         0  0.001947 -0.009048  0.009350 -0.005333
#
#               vec4      vec5      vec6      vec7  ...  cat_Electronics  \
# train_id                                          ...
# 0        -0.002364 -0.014765  0.012060 -0.008765  ...                0
# 1        -0.010722  0.013957 -0.008687  0.007710  ...                1
# 2         0.012070 -0.011089 -0.013029 -0.001692  ...                0
# 3         0.010533 -0.000997  0.001640 -0.007969  ...                0
# 4        -0.004083 -0.001077 -0.014431  0.003161  ...                0
# ...            ...       ...       ...       ...  ...              ...
# 1482530  -0.015538 -0.010825 -0.006603  0.013614  ...                0
# 1482531  -0.011221  0.000128 -0.002075  0.001431  ...                0
# 1482532  -0.010625 -0.014848  0.013021 -0.013314  ...                0
# 1482533  -0.000295  0.014102 -0.009837 -0.003777  ...                0
# 1482534  -0.008319  0.006095  0.003712 -0.001768  ...                0
#
#           cat_Fashion  cat_Food and Beverage  cat_Furniture and Decor  \
# train_id
# 0                   1                      0                        0
# 1                   0                      0                        0
# 2                   1                      0                        0
# 3                   0                      0                        1
# 4                   1                      0                        0
# ...               ...                    ...                      ...
# 1482530             1                      0                        0
# 1482531             1                      0                        0
# 1482532             0                      0                        0
# 1482533             0                      0                        1
# 1482534             1                      0                        0
#
#           cat_Health and Wellness  cat_Household Items  cat_Media  \
# train_id
# 0                               0                    0          0
# 1                               0                    0          0
# 2                               0                    0          0
# 3                               0                    0          0
# 4                               0                    0          0
# ...                           ...                  ...        ...
# 1482530                         0                    0          0
# 1482531                         0                    0          0
# 1482532                         0                    1          0
# 1482533                         0                    0          0
# 1482534                         0                    0          0
#
#           cat_Office Equipment  cat_Pet Care  cat_Toys and Hobbies
# train_id
# 0                            0             0                     0
# 1                            0             0                     0
# 2                            0             0                     0
# 3                            0             0                     0
# 4                            0             0                     0
# ...                        ...           ...                   ...
# 1482530                      0             0                     0
# 1482531                      0             0                     0
# 1482532                      0             0                     0
# 1482533                      0             0                     0
# 1482534                      0             0                     0
#
# [1481661 rows x 47 columns]

# %%
y_train
# Out:
# train_id
# 0          10.0
# 1          52.0
# 2          10.0
# 3          35.0
# 4          44.0
#            ...
# 1482530    20.0
# 1482531    14.0
# 1482532    12.0
# 1482533    45.0
# 1482534    22.0
# Name: price, Length: 1481661, dtype: float64

# %%
test_df
# Out:
#                                              name  item_condition_id  \
# test_id
# 0        Breast cancer "I fight like a girl" ring                  1
# 1        25 pcs NEW 7.5"x12" Kraft Bubble Mailers                  1
# 2                                       Coach bag                  1
# 3                                   Floral Kimono                  2
# 4                                Life after Death                  3
# ...                                           ...                ...
# 693354              Quartz crystal on Flint stone                  1
# 693355               It Cosmetics - Travel Bundle                  1
# 693356                  Galaxy S8 hard shell case                  1
# 693357                       Hi low floral kimono                  2
# 693358      FREESHIP 2 Floral Scrub Tops, medium.                  2
#
#                                              category_name    brand_name  \
# test_id
# 0                                      Women/Jewelry/Rings           NaN
# 1                  Other/Office supplies/Shipping Supplies           NaN
# 2           Vintage & Collectibles/Bags and Purses/Handbag         Coach
# 3                                  Women/Sweaters/Cardigan           NaN
# 4                      Other/Books/Religion & Spirituality           NaN
# ...                                                    ...           ...
# 693354                  Home/Home Décor/Home Décor Accents           NaN
# 693355                           Beauty/Makeup/Makeup Sets  IT Cosmetics
# 693356   Electronics/Cell Phones & Accessories/Cases, C...           NaN
# 693357                            Women/Swimwear/Cover-Ups           NaN
# 693358                       Women/Tops & Blouses/T-Shirts           NaN
#
#          shipping                                   item_description
# test_id
# 0               1                                             Size 7
# 1               1  25 pcs NEW 7.5"x12" Kraft Bubble Mailers Lined...
# 2               1  Brand new coach bag. Bought for [rm] at a Coac...
# 3               0  -floral kimono -never worn -lightweight and pe...
# 4               1  Rediscovering life after the loss of a loved o...
# ...           ...                                                ...
# 693354          0  Flint/Quartz cluster. Self mined ✨measures 3x2...
# 693355          1  It Cosmetics travel bundle. Includes: Brow pow...
# 693356          1                    New. Free shipping Basstop case
# 693357          0  Floral kimono. Tropical print. Open front. Hi ...
# 693358          1  2 Floral scrub tops. Worn less than 5 times ea...
#
# [693359 rows x 6 columns]

# %%
test_df = preprocess(test_df)
test_df.to_csv('test_pp2.csv')
test_df
# Out:
#          item_condition_id  shipping      vec0      vec1      vec2      vec3  \
# test_id
# 0                        1         1 -0.009170 -0.012634 -0.006592 -0.006995
# 1                        1         1 -0.008170 -0.009984  0.015215  0.007817
# 2                        1         1 -0.013603  0.008433 -0.014415  0.009674
# 3                        2         0  0.010091  0.013853 -0.008173  0.011594
# 4                        3         1  0.003682  0.008625  0.009014 -0.014524
# ...                    ...       ...       ...       ...       ...       ...
# 693354                   1         0 -0.014980  0.013684  0.005517 -0.003117
# 693355                   1         1 -0.001568 -0.009575  0.005763  0.009205
# 693356                   1         1 -0.014832  0.005456  0.010401 -0.008532
# 693357                   2         0  0.009433  0.003937  0.009730 -0.010670
# 693358                   2         1 -0.006598 -0.005606 -0.012231  0.014159
#
#              vec4      vec5      vec6      vec7  ...  cat_Electronics  \
# test_id                                          ...
# 0       -0.006046 -0.006768  0.011584  0.001173  ...                0
# 1        0.004612  0.010948 -0.007198  0.004576  ...                0
# 2        0.005552 -0.001889  0.006846  0.011518  ...                0
# 3       -0.013484  0.000744  0.001803 -0.006956  ...                0
# 4        0.004851 -0.011560  0.001164 -0.006535  ...                0
# ...           ...       ...       ...       ...  ...              ...
# 693354   0.007499 -0.015458 -0.014831 -0.002818  ...                0
# 693355   0.015547 -0.004135  0.014392 -0.005171  ...                0
# 693356   0.003531  0.009408  0.005307  0.008305  ...                1
# 693357   0.010163  0.012626 -0.003105  0.011060  ...                0
# 693358  -0.012769  0.002601  0.015418 -0.013321  ...                0
#
#          cat_Fashion  cat_Food and Beverage  cat_Furniture and Decor  \
# test_id
# 0                  1                      0                        0
# 1                  0                      0                        0
# 2                  1                      0                        0
# 3                  1                      0                        0
# 4                  0                      0                        0
# ...              ...                    ...                      ...
# 693354             0                      0                        1
# 693355             0                      0                        0
# 693356             0                      0                        0
# 693357             1                      0                        0
# 693358             1                      0                        0
#
#          cat_Health and Wellness  cat_Household Items  cat_Media  \
# test_id
# 0                              0                    0          0
# 1                              0                    0          0
# 2                              0                    0          0
# 3                              0                    0          0
# 4                              0                    0          1
# ...                          ...                  ...        ...
# 693354                         0                    0          0
# 693355                         0                    0          0
# 693356                         0                    0          0
# 693357                         0                    0          0
# 693358                         0                    0          0
#
#          cat_Office Equipment  cat_Pet Care  cat_Toys and Hobbies
# test_id
# 0                           0             0                     0
# 1                           1             0                     0
# 2                           0             0                     0
# 3                           0             0                     0
# 4                           0             0                     0
# ...                       ...           ...                   ...
# 693354                      0             0                     0
# 693355                      0             0                     0
# 693356                      0             0                     0
# 693357                      0             0                     0
# 693358                      0             0                     0
#
# [693359 rows x 47 columns]
